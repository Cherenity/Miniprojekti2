# %%
import pandas as pd
df = pd.read_csv('7-9_22_SF Crime Data Export — 2023-03-10 — 05.12.40 PM.csv', sep=',')
df = df.rename(columns={'incident_datetime': 'datetime', 'analysis_neighborhood': 'neighborhood', 'incident_category' : 'incidentCategory'})
df = df.rename(columns = {'police_district' : 'policeDistrict', 'incident_description' : 'incidentDescription'})
df.drop(df.columns[[0, 4, 5, 8]], axis=1, inplace=True)
df = df.reindex(columns=['incidentCategory', 'incidentDescription', 'neighborhood', 'policeDistrict', 'datetime'])
df
# Out:
#           incidentCategory                                incidentDescription  \
# 0                    Fraud            Fraudulent Use Of Automated Teller Card
# 1                    Fraud  Fraudulent Game or Trick, Obtaining Money or P...
# 2       Malicious Mischief          Malicious Mischief, Vandalism to Property
# 3      Motor Vehicle Theft                              Vehicle, Stolen, Auto
# 4                    Fraud            Fraudulent Use Of Automated Teller Card
# ...                    ...                                                ...
# 25004        Larceny Theft                  Theft, From Locked Vehicle, >$950
# 25005  Other Miscellaneous                         Driving, No License Issued
# 25006        Larceny Theft                        Theft, Vehicle Strip, >$950
# 25007       Missing Person                                      Missing Adult
# 25008  Motor Vehicle Theft                              Vehicle, Stolen, Auto
#
# ...
