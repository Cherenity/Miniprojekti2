# %%
import pandas as pd

# %% [markdown]
# ### 1. Scripts for reading crime data .csv files and concate into one dataframe: crime_sf

# %%
rikos1 = pd.read_csv("7-9_22_SF Crime Data Export — 2023-03-10 — 05.12.40 PM.csv", sep =',')
rikos2 = pd.read_csv("10-12_22_SF Crime Data Export — 2023-03-10 — 05.10.49 PM.csv", sep =',')
rikos3 = pd.read_csv("1-3_23_SF Crime Data Export — 2023-03-10 — 05.08.38 PM.csv", sep =',')

crime_sf = pd.concat([rikos1, rikos2, rikos3], ignore_index=True)
crime_sf
# Out:
#              incident_date    incident_datetime analysis_neighborhood  \
# 0      2022-07-01 00:00:00  2022-07-01 00:00:00          Inner Sunset
# 1      2022-07-01 00:00:00  2022-07-01 00:00:00              Nob Hill
# 2      2022-07-01 00:00:00  2022-07-01 00:00:00                Marina
# 3      2022-07-01 00:00:00  2022-07-01 00:01:00               Mission
# 4      2022-07-01 00:00:00  2022-07-01 00:01:00             Excelsior
# ...                    ...                  ...                   ...
# 64569  2023-03-08 00:00:00  2023-03-08 20:30:00               Mission
# 64570  2023-03-08 00:00:00  2023-03-08 20:30:00             Chinatown
# 64571  2023-03-08 00:00:00  2023-03-08 21:24:00               Mission
# 64572  2023-03-08 00:00:00  2023-03-08 22:29:00               Mission
# 64573  2023-03-08 00:00:00  2023-03-08 22:29:00               Mission
#
#               incident_category       incident_category.1  \
# 0                         Fraud                     Fraud
# ...

# %% [markdown]
# ### 2. Renaming columns, dropping non-relevant columns , reordering the columns

# %%
# Nimetään uudelleen sarakkeet
crime_sf = crime_sf.rename(columns={'incident_datetime': 'datetime', 'analysis_neighborhood': 'neighborhood', 'incident_category' : 'incidentCategory', 'incident_description' : 'incidentDescription'})
# Poistetaan turhat sarakkeet
crime_sf.drop(crime_sf.columns[[0, 4, 5, 6, 8]], axis=1, inplace=True)
# Järjestetään sarakkeet
crime_sf = crime_sf.reindex(columns=['incidentCategory', 'incidentDescription', 'neighborhood', 'datetime'])
crime_sf
# Out:
#                incidentCategory  \
# 0                         Fraud
# 1                         Fraud
# 2            Malicious Mischief
# 3           Motor Vehicle Theft
# 4                         Fraud
# ...                         ...
# 64569  Traffic Violation Arrest
# 64570             Larceny Theft
# 64571       Other Miscellaneous
# 64572       Other Miscellaneous
# 64573  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...                                                  ...           ...
# 64569                           Traffic Violation Arrest       Mission
# ...

# %% [markdown]
# ## 3. Transform datetime column into datetime-object
# ###       Add column for the hour of the incident

# %%
# Muunnetaan sarake 'datetime' datetime muotoiseksi objektiksi 
crime_sf['datetime'] = pd.to_datetime(crime_sf['datetime'])

# #Lisätään vuorokauden tunti (muodossa 00, 01, 02 jne.) jolloin rikos tapahtunut
crime_sf['hour'] = crime_sf['datetime'].dt.strftime('%H')
crime_sf
# Out:
#                incidentCategory  \
# 0                         Fraud
# 1                         Fraud
# 2            Malicious Mischief
# 3           Motor Vehicle Theft
# 4                         Fraud
# ...                         ...
# 64569  Traffic Violation Arrest
# 64570             Larceny Theft
# 64571       Other Miscellaneous
# 64572       Other Miscellaneous
# 64573  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...                                                  ...           ...
# 64569                           Traffic Violation Arrest       Mission
# ...

# %% [markdown]
# ###  4. Add datekey column (weather) in format of YYYYMMDDHH

# %%
crime_sf['weather'] = (crime_sf['datetime'].dt.strftime('%Y%m%d') + crime_sf['hour']).astype(int)
crime_sf
# Out:
#                incidentCategory  \
# 0                         Fraud
# 1                         Fraud
# 2            Malicious Mischief
# 3           Motor Vehicle Theft
# 4                         Fraud
# ...                         ...
# 64569  Traffic Violation Arrest
# 64570             Larceny Theft
# 64571       Other Miscellaneous
# 64572       Other Miscellaneous
# 64573  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...                                                  ...           ...
# 64569                           Traffic Violation Arrest       Mission
# ...

# %% [markdown]
# ###  5. Replace Nan-values in 'incidentCategory' column with incidentDescriptions

# %%
crime_sf['incidentCategory'] = crime_sf['incidentCategory'].fillna(crime_sf['incidentDescription'])

# %%
crimegb= crime_sf.groupby(['incidentCategory', 'incidentDescription']).count()
crimegb
# Out:
#                                                                      neighborhood  \
# incidentCategory incidentDescription
# Arson            Arson                                                        131
#                  Arson of Vehicle                                              61
#                  Arson, Attempted                                              13
#                  Arson, Commercial Building                                    21
#                  Arson, Inhabited Dwelling                                     18
# ...                                                                           ...
# Weapons Offense  Firearm, Discharging Within City Limits                      171
#                  Weapon, Carrying Concealed                                    71
#                  Weapon, Carrying Concealed with Felony or Narco...            14
#                  Weapon, Deadly, Imitation or Laser Scope, Exhib...           410
# ...

# %%
crime_sf.groupby('incidentCategory').nunique()
# Out:
#                                                     incidentDescription  \
# incidentCategory
# Arson                                                                 8
# Assault                                                              33
# Auto Impounded                                                        1
# Burglary                                                             41
# Case Closure                                                          1
# Civil Sidewalks                                                       1
# Courtesy Report                                                       1
# Cryptocurrency Related Crime (secondary code only)                    1
# Disorderly Conduct                                                   22
# Driving, Stunt Vehicle/Street Racing                                  1
# Drug Offense                                                         37
# Drug Violation                                                        1
# ...

# %% [markdown]
# ### 6. Replace incidentCategory-names with spelling errors with actual category names

# %%
crime_sf['incidentCategory'] = crime_sf['incidentCategory'].replace({'Weapons Offence': 'Weapons Offense', 'Motor Vehicle Theft?': 'Motor Vehicle Theft','Human Trafficking (A), Commercial Sex Acts':'Human Trafficking, Commercial Sex Acts'})
crime_sf.groupby('incidentCategory').nunique()
# Out:
#                                                     incidentDescription  \
# incidentCategory
# Arson                                                                 8
# Assault                                                              33
# Auto Impounded                                                        1
# Burglary                                                             41
# Case Closure                                                          1
# Civil Sidewalks                                                       1
# Courtesy Report                                                       1
# Cryptocurrency Related Crime (secondary code only)                    1
# Disorderly Conduct                                                   22
# Driving, Stunt Vehicle/Street Racing                                  1
# Drug Offense                                                         37
# Drug Violation                                                        1
# ...

# %% [markdown]
# ### 7. After reviewing the categories, list categories that are irrelevant and to be deleted

# %%
poistettavat_kategoriat = ['Case Closure', 'Civil Sidewalks', 'Courtesy Report', 'Fire Report', 'Lost Property', 'Miscellaneous Investigation', 'Missing Person', 'Non-Criminal', 'Recovered Vehicle', 'Stolen Property', 'Suspicious', 'Suspicious Occ', 'Vehicle Impounded', 'Vehicle Misplaced', 'Other','Traffic Collision', 'Warrant','Auto Impounded', 'SFMTA Employee-Non Operator/Station Agent-Other Employee', 'SFMTA Muni Transit Operator-Bus/LRV', 'Vehicle, Seizure Order', 'Cryptocurrency Related Crime (secondary code only)', 'Theft, Animal, Att.', 'Gun Violence Restraining Order']

# %%
crime_sf1 = crime_sf.drop(crime_sf[crime_sf['incidentCategory'].isin(poistettavat_kategoriat)].index)
crime_sf1
# Out:
#                incidentCategory  \
# 0                         Fraud
# 1                         Fraud
# 2            Malicious Mischief
# 3           Motor Vehicle Theft
# 4                         Fraud
# ...                         ...
# 64569  Traffic Violation Arrest
# 64570             Larceny Theft
# 64571       Other Miscellaneous
# 64572       Other Miscellaneous
# 64573  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...                                                  ...           ...
# 64569                           Traffic Violation Arrest       Mission
# ...

# %%
crime_sf.groupby('incidentCategory').nunique()
# Out:
#                                                     incidentDescription  \
# incidentCategory
# Arson                                                                 8
# Assault                                                              33
# Auto Impounded                                                        1
# Burglary                                                             41
# Case Closure                                                          1
# Civil Sidewalks                                                       1
# Courtesy Report                                                       1
# Cryptocurrency Related Crime (secondary code only)                    1
# Disorderly Conduct                                                   22
# Driving, Stunt Vehicle/Street Racing                                  1
# Drug Offense                                                         37
# Drug Violation                                                        1
# ...

# %% [markdown]
# ### 8. After the review of categories 'Other Miscellaneous' and 'Other Offenses', create new, more accurate categories that fit the incident description

# %%
crime_sf1['incidentDescription'] = crime_sf1['incidentDescription'].replace({'Accessory or Aid Or Harbor Felon':'Accessory, Aid Or Harbor of Felon',
'Aerosol Paint & Marker Pens, Display & Storage':'Display & Storage of Aerosol Paint & Marker Pens',
'Air Gun, Possession':'Posession of Air Gun',
'Alcohol, Consuming In Public View':'Public Consuming of Alcohol',
'Bomb Threat or False Report of Bomb':'Bomb Threat or False Report of Bomb',
'Burglary Tools, Possession Of':'Possession Of Burglary Tools',
'Burglary Tools, Possession Of w/prior':'Possession Of Burglary Tools',
'Conceal Crime or Withhold Evidence, Accepting Payment to':'Accepting Payment to Conceal Crime or Withhold Evidence',
'Defrauding Gas Station/Taxi Driver':'Defrauding',
'Defrauding Of Vehicle Repairman':'Defrauding',
'Defrauding Providers of Food, Fuel, Services, or Accommodations':'Defrauding',
'Discharging Offensive or Injurious Substance in Public Area':'Discharging Offensive or Injurious Substance',
'Dissuading Witness, Victim':'Dissuading/Threatening Of A Witness',
'Dissuading/Threatening Of A Witness':'Dissuading/Threatening Of A Witness',
'Driving While Under The Influence Of Alcohol':'Driving While Under The Influence Of Alcohol',
'Driving While Under The Influence Of Alcohol, w/Injury':'Driving While Under The Influence Of Alcohol',
'Driving While Under The Influence Of Drugs':'Driving While Under The Influence Of Drugs',
'Driving While Under The Influence Of Drugs, w/Injury':'Driving While Under The Influence Of Drugs',
'Driving, Failure To Heed Red Light And Siren':'Traffic Violation',
'Driving, License Suspended or Revoked':'Traffic Violation',
'Driving, No License Issued':'Traffic Violation',
'Driving, Reckless':'Traffic Violation',
'Driving, Reckless, with Injury':'Traffic Violation',
'Driving, Speeding':'Traffic Violation',
'Evading a Police Officer Recklessly':'Evading a Police',
'Evading a Police Officer, Injury or Death':'Evading a Police',
'Evading a Police Vehicle or Bicycle':'Evading a Police',
'Extortion or Blackmail':'Extortion',
'Extortion, Attempted':'Extortion',
'False Report of Emergency':'Stating False Report',
'False Report of Felony or Misdemeanor':'Stating False Report',
'Federal Law Violation (general)':'Federal Law Violation',
'Fire Code Violation (general)':'Fire Code Violation',
'Firearm with Altered Identification':'Firearm with Altered Identification',
'Firefighter, Interfering with':'Interfering with Firefighter',
'Fireworks, Exploding':'Fireworks Violation',
'Fireworks, Possession of any within SF, incl. Safe & Sane""':'Fireworks Violation',
'Fireworks, Throw at Person or Discharge in Crowd':'Fireworks Violation',
'Flammable or Explosive Device, Possession':'Weapons Carrying Etc',
'Identification To Peace Officer, False':'False Identification',
'Impersonating A Police Officer':'Impersonating A Police Officer',
'Injuring Phone, Cable TV, or Other Line':'Injuring Phone, Cable TV, or Other Line',
'Interfering, W/ Police Officer':'Interfering with Police Officer',
'Kidnapping (Adult victim)':'Kidnapping',
'Kidnapping during Robbery':'Kidnapping',
'Kidnapping, Attempted (Adult victim)':'Kidnapping',
'Lodging Without Permission':'Lodging',
'Loitering and Peeking into Inhabited Structure':'Loitering',
'Loitering Without Lawful Business With Owner or Occupant':'Loitering',
'Maintaining A Public Nuisance':'Disorderly Conduct',
'Municipal Code Violation (general)':'Code Violation',
'Municipal Police Code Violation (general)':'Code Violation',
'Other Offenses Against Public Justice':'Offense Against Public Justice',
'Park Code Violation (general)':'Code Violation',
'Peddling Without A License':'Permit Violation',
'Permit Violation, Advertising Distributors':'Permit Violation',
'Permit Violation, Entertainment':'Permit Violation',
'Permit Violation, Police (general)':'Permit Violation',
'Public Transit Crimes-Infractions':'Public Transit Crimes',
'Public Transit, Acts Against':'Public Transit Crimes',
'Rail Transit, Entering, Remaining, or Hindering Operation of':'Public Transit Crimes',
'Resisting Peace Officer, causing Their Serious Injury or Death':'Resisting Peace Officer, causing Their Serious Injury or Death',
'Resisting, Delaying, or Obstructing  Peace Officer Duties':'Resisting, Delaying, or Obstructing  Peace Officer Duties',
'Soliciting Commission Of A Crime':'Soliciting',
'Soliciting, Aggressive':'Soliciting',
'State Code Felony (general)':'Code Felony',
'State Code Misdemeanor (general)':'Code Misdemenaor',
'Threat or Force to Resist Executive Officer':'Threatening',
'Threatening School or Public Employee':'Threatening',
'Throwing Injurious Substance on Highway':'Throving Injurious Substance',
'Throwing Object at Common Carrier, Passenger or Freight':'Throving Injurious Object',
'Trespassing':'Trespassing',
'Trespassing On Railroad Trains':'Trespassing',
'Trespassing or Loitering Near Posted Industrial Property':'Trespassing',
'Vehicle Alarm Code Grabbing Device, Possess or Use':'Possession Of Burglary Tools',
'Vehicle, Disabled Placard Violation':'Vehicle Violation',
'Vehicle, Open Container Of Alcohol In':'Vehicle Violation',
'Vehicle, Throwing Substance At':'Throving Injurious Object',
'Weapon, Taking or Attempting to Take from Peace Officer':'Weapons Offense',
'Wearing Mask or Disguise for Unlawful Purpose':'Disguise for Unlawful Purpose'
})
crime_sf1
# Out:
#                incidentCategory  \
# 0                         Fraud
# 1                         Fraud
# 2            Malicious Mischief
# 3           Motor Vehicle Theft
# 4                         Fraud
# ...                         ...
# 64569  Traffic Violation Arrest
# 64570             Larceny Theft
# 64571       Other Miscellaneous
# 64572       Other Miscellaneous
# 64573  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...                                                  ...           ...
# 64569                           Traffic Violation Arrest       Mission
# ...

# %%
crime_sf1[crime_sf1['incidentCategory'] == 'Other Offenses']
# Out:
#       incidentCategory       incidentDescription           neighborhood  \
# 24      Other Offenses  License Plate, Recovered             Tenderloin
# 63      Other Offenses  License Plate, Recovered       Presidio Heights
# 224     Other Offenses                Defrauding          Outer Mission
# 274     Other Offenses  License Plate, Recovered         Haight Ashbury
# 419     Other Offenses  License Plate, Recovered                Mission
# ...                ...                       ...                    ...
# 64451   Other Offenses  License Plate, Recovered            Mission Bay
# 64456   Other Offenses  License Plate, Recovered       Golden Gate Park
# 64459   Other Offenses  License Plate, Recovered       Golden Gate Park
# 64515   Other Offenses  License Plate, Recovered  Bayview Hunters Point
# 64540   Other Offenses      License Plate, Found      Visitacion Valley
#
#                  datetime hour     weather
# 24    2022-07-01 02:14:00   02  2022070102
# ...

# %% [markdown]
# ### 9. After the review of newly created categories from 'Other Miscellaneous' and 'Other Offenses',  list the irrelelevant incidents to be deleted

# %%
poistettavat_rivit = ['Conspiracy', 'Escape From Hospital With Force', 'Escapes', 'False Imprisonment', 'Investigative Detention', 'License Plate, Found', 'License Plate, Lost', 'License Plate, Recovered', 'Littering or Dumping that Creates Traffic Hazard', 'Obscene Movies or Acts', 'Parole Violation, Adult', 'Probation Violation', 'Unusual Occurrence']

# %%
crime_sf1 = crime_sf1[~crime_sf1['incidentDescription'].isin(poistettavat_rivit)]
crime_sf1
# Out:
#                incidentCategory  \
# 0                         Fraud
# 1                         Fraud
# 2            Malicious Mischief
# 3           Motor Vehicle Theft
# 4                         Fraud
# ...                         ...
# 64568       Motor Vehicle Theft
# 64569  Traffic Violation Arrest
# 64570             Larceny Theft
# 64572       Other Miscellaneous
# 64573  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...                                                  ...           ...
# 64568                              Vehicle, Stolen, Auto     Japantown
# ...

# %%
crime_sf1[crime_sf1['incidentCategory'] == 'Other Offenses']
# Out:
#       incidentCategory                           incidentDescription  \
# 224     Other Offenses                                    Defrauding
# 674     Other Offenses                              Permit Violation
# 1844    Other Offenses  Discharging Offensive or Injurious Substance
# 3010    Other Offenses                         Public Transit Crimes
# 3181    Other Offenses                         Public Transit Crimes
# ...                ...                                           ...
# 61141   Other Offenses                                Code Violation
# 61264   Other Offenses                                Code Violation
# 61799   Other Offenses                                Code Violation
# 62336   Other Offenses                   Public Consuming of Alcohol
# 62555   Other Offenses                                Code Violation
#
#                 neighborhood            datetime hour     weather
# 224            Outer Mission 2022-07-01 23:10:00   23  2022070123
# ...

# %% [markdown]
# ###  10. Replace the original categories ('Other Miscellaneous' and 'Other Offenses') with reviewed new categories

# %%
crime_sf1.loc[crime_sf1["incidentCategory"] == "Other Offenses", "incidentCategory"] = crime_sf1.loc[crime_sf1["incidentCategory"] == "Other Offenses", "incidentDescription"]

# %%
crime_sf1[crime_sf1['incidentCategory'] == 'Other Offenses']
# Out:
# Empty DataFrame
# Columns: [incidentCategory, incidentDescription, neighborhood, datetime, hour, weather]
# Index: []

# %%
crime_sf1.loc[crime_sf1["incidentCategory"] == "Other Miscellaneous", "incidentCategory"] = crime_sf1.loc[crime_sf1["incidentCategory"] == "Other Miscellaneous", "incidentDescription"]

# %%
crime_sf1[crime_sf1['incidentCategory'] == 'Other Miscellaneous']
# Out:
# Empty DataFrame
# Columns: [incidentCategory, incidentDescription, neighborhood, datetime, hour, weather]
# Index: []

# %%
crime_sf1.groupby('incidentCategory').nunique()
# Out:
#                                                     incidentDescription  \
# incidentCategory
# Accepting Payment to Conceal Crime or Withhold ...                    1
# Accessory, Aid Or Harbor of Felon                                     1
# Arson                                                                 8
# Assault                                                              32
# Bomb Threat or False Report of Bomb                                   1
# ...                                                                 ...
# Trespassing                                                           1
# Vandalism                                                             1
# Vehicle Violation                                                     1
# Weapons Carrying Etc                                                 18
# Weapons Offense                                                      13
#
#                                                     neighborhood  datetime  \
# ...

# %%
crime_sf1
# Out:
#                incidentCategory  \
# 0                         Fraud
# 1                         Fraud
# 2            Malicious Mischief
# 3           Motor Vehicle Theft
# 4                         Fraud
# ...                         ...
# 64568       Motor Vehicle Theft
# 64569  Traffic Violation Arrest
# 64570             Larceny Theft
# 64572         Traffic Violation
# 64573  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...                                                  ...           ...
# 64568                              Vehicle, Stolen, Auto     Japantown
# ...

# %% [markdown]
#  ### 11. The column 'neighbourhood' stille has NaN values. Review the content and drop rows as irrelevant

# %%
crime_sf1 = crime_sf1.dropna()
crime_sf1
# Out:
#                incidentCategory  \
# 0                         Fraud
# 1                         Fraud
# 2            Malicious Mischief
# 3           Motor Vehicle Theft
# 4                         Fraud
# ...                         ...
# 64568       Motor Vehicle Theft
# 64569  Traffic Violation Arrest
# 64570             Larceny Theft
# 64572         Traffic Violation
# 64573  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...                                                  ...           ...
# 64568                              Vehicle, Stolen, Auto     Japantown
# ...

# %% [markdown]
# ### 12. Reset the index

# %%
crime_sf1 = crime_sf1.reset_index()
crime_sf1
# Out:
#        index          incidentCategory  \
# 0          0                     Fraud
# 1          1                     Fraud
# 2          2        Malicious Mischief
# 3          3       Motor Vehicle Theft
# 4          4                     Fraud
# ...      ...                       ...
# 46328  64568       Motor Vehicle Theft
# 46329  64569  Traffic Violation Arrest
# 46330  64570             Larceny Theft
# 46331  64572         Traffic Violation
# 46332  64573  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...

# %% [markdown]
# ### 13. Drop the old 'index' column

# %%
crime_sf1 = crime_sf1.drop('index', axis=1)
crime_sf1
# Out:
#                incidentCategory  \
# 0                         Fraud
# 1                         Fraud
# 2            Malicious Mischief
# 3           Motor Vehicle Theft
# 4                         Fraud
# ...                         ...
# 46328       Motor Vehicle Theft
# 46329  Traffic Violation Arrest
# 46330             Larceny Theft
# 46331         Traffic Violation
# 46332  Traffic Violation Arrest
#
#                                      incidentDescription  neighborhood  \
# 0                Fraudulent Use Of Automated Teller Card  Inner Sunset
# 1      Fraudulent Game or Trick, Obtaining Money or P...      Nob Hill
# 2              Malicious Mischief, Vandalism to Property        Marina
# 3                                  Vehicle, Stolen, Auto       Mission
# 4                Fraudulent Use Of Automated Teller Card     Excelsior
# ...                                                  ...           ...
# 46328                              Vehicle, Stolen, Auto     Japantown
# ...

# %% [markdown]
# ### 14. Drop the  'incidentDescription' column

# %%
crime_sf1 = crime_sf1.drop('incidentDescription', axis=1)
crime_sf1
# Out:
#                incidentCategory  neighborhood            datetime hour  \
# 0                         Fraud  Inner Sunset 2022-07-01 00:00:00   00
# 1                         Fraud      Nob Hill 2022-07-01 00:00:00   00
# 2            Malicious Mischief        Marina 2022-07-01 00:00:00   00
# 3           Motor Vehicle Theft       Mission 2022-07-01 00:01:00   00
# 4                         Fraud     Excelsior 2022-07-01 00:01:00   00
# ...                         ...           ...                 ...  ...
# 46328       Motor Vehicle Theft     Japantown 2023-03-08 20:30:00   20
# 46329  Traffic Violation Arrest       Mission 2023-03-08 20:30:00   20
# 46330             Larceny Theft     Chinatown 2023-03-08 20:30:00   20
# 46331         Traffic Violation       Mission 2023-03-08 22:29:00   22
# 46332  Traffic Violation Arrest       Mission 2023-03-08 22:29:00   22
#
#           weather
# 0      2022070100
# 1      2022070100
# 2      2022070100
# 3      2022070100
# ...

# %% [markdown]
# ### 15. Set the index start from 1->

# %%
crime_sf1.index = crime_sf1.index + 1
crime_sf1
# Out:
#                incidentCategory  neighborhood            datetime hour  \
# 1                         Fraud  Inner Sunset 2022-07-01 00:00:00   00
# 2                         Fraud      Nob Hill 2022-07-01 00:00:00   00
# 3            Malicious Mischief        Marina 2022-07-01 00:00:00   00
# 4           Motor Vehicle Theft       Mission 2022-07-01 00:01:00   00
# 5                         Fraud     Excelsior 2022-07-01 00:01:00   00
# ...                         ...           ...                 ...  ...
# 46329       Motor Vehicle Theft     Japantown 2023-03-08 20:30:00   20
# 46330  Traffic Violation Arrest       Mission 2023-03-08 20:30:00   20
# 46331             Larceny Theft     Chinatown 2023-03-08 20:30:00   20
# 46332         Traffic Violation       Mission 2023-03-08 22:29:00   22
# 46333  Traffic Violation Arrest       Mission 2023-03-08 22:29:00   22
#
#           weather
# 1      2022070100
# 2      2022070100
# 3      2022070100
# 4      2022070100
# ...

# %%
crimegb= crime_sf1.groupby('incidentCategory').nunique()
crimegb.index
# Out:
# Index(['Accepting Payment to Conceal Crime or Withhold Evidence',
#        'Accessory, Aid Or Harbor of Felon', 'Arson', 'Assault',
#        'Bomb Threat or False Report of Bomb', 'Burglary', 'Code Felony',
#        'Code Misdemenaor', 'Code Violation', 'Defrauding',
#        'Discharging Offensive or Injurious Substance',
#        'Disguise for Unlawful Purpose', 'Disorderly Conduct',
#        'Display & Storage of Aerosol Paint & Marker Pens',
#        'Dissuading/Threatening Of A Witness',
#        'Driving While Under The Influence Of Alcohol',
#        'Driving While Under The Influence Of Drugs',
#        'Driving, Stunt Vehicle/Street Racing', 'Drug Offense',
#        'Drug Violation', 'Embezzlement', 'Evading a Police', 'Extortion',
#        'False Identification', 'Federal Law Violation', 'Fire Code Violation',
#        'Firearm with Altered Identification', 'Fireworks Violation',
#        'Fireworks, Possession of any within SF,  incl. Safe & Sane""',
# ...

# %% [markdown]
# ### 16. Create copy of the working df

# %%
CRIME_FILE = crime_sf1.copy()
CRIME_FILE
# Out:
#                incidentCategory  neighborhood            datetime hour  \
# 1                         Fraud  Inner Sunset 2022-07-01 00:00:00   00
# 2                         Fraud      Nob Hill 2022-07-01 00:00:00   00
# 3            Malicious Mischief        Marina 2022-07-01 00:00:00   00
# 4           Motor Vehicle Theft       Mission 2022-07-01 00:01:00   00
# 5                         Fraud     Excelsior 2022-07-01 00:01:00   00
# ...                         ...           ...                 ...  ...
# 46329       Motor Vehicle Theft     Japantown 2023-03-08 20:30:00   20
# 46330  Traffic Violation Arrest       Mission 2023-03-08 20:30:00   20
# 46331             Larceny Theft     Chinatown 2023-03-08 20:30:00   20
# 46332         Traffic Violation       Mission 2023-03-08 22:29:00   22
# 46333  Traffic Violation Arrest       Mission 2023-03-08 22:29:00   22
#
#           weather
# 1      2022070100
# 2      2022070100
# 3      2022070100
# 4      2022070100
# ...

# %% [markdown]
# ### 17. Save the not encoded dataframe as .csv file

# %%
CRIME_FILE.to_csv("CRIME_FILE.csv", sep =';')
